# %%
import numpy as np
import matplotlib.pyplot as plt


def v(t):
    return 18*t - 9*t**2
    
    
def s(t):
    return [np.trapz(v(t)[t <= i], t[t <= i]) for i in t]


t = np.linspace(0, 15)

s_values = s(t)

plt.plot(t, s_values)
plt.xlabel('Time')
plt.ylabel('Pyt')
plt.show()
