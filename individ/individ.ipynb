# %% [markdown]
# Найдите путь, который пройдет тело от начала движения до возвращения в исходную точку, если его скорость 18t -9t^2 с помощью numpy и построить график

# %%
import numpy as np
import matplotlib.pyplot as plt


#Функция скорости 
def v(t):
    return 18*t - 9*t**2
    

#Функция перемещения
def s(t):
    return [np.trapz(v(t)[t <= i], t[t <= i]) for i in t]


t = np.linspace(0, 15)

s_values = s(t)

#Построение графика
plt.plot(t, s_values)
plt.xlabel('Time')
plt.ylabel('Pyt')
plt.show()

# %% [markdown]
# Найти объем тела вращения вокруг оси 0х , ограниченной прямыми у=0, х=0, у=х**2, х=4

# %%
def f(x):
    return x**2

#Задаем массив значений х
x = np.linspace(0, 4, 100)

#Вычисляем
y = f(x)
y_kb = y**2

#Вычисляем интеграл
integral = np.trapz(y_kb, x)
volume = np.pi * integral

print("Объем тела вращения: ", volume)

#Cтроим график
plt.plot(x, y)
plt.fill_between(x, y, color='lightblue')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Объем тела вращения:  643.507584632967
